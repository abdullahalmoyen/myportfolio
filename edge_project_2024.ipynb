# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahalmoyen/myportfolio/blob/main/edge_project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Project: Take a csv file, import the file in your python program, visualize and analyze (description summary from the given graph) the data.
#line graph
#pie graph
#Bar graph
#use seaborn and bokeh library for your data visualization.

# %%
#Taking csv file
#import csv file

import pandas as pd

df = pd.read_csv('/content/environmental_data.csv')
print(df)
# Out:
#     Temperature  Humidity  Pressure
# 0            23        63       947
# 1            39        87      1073
# 2             8         8       941
# 3            46        50       930
# 4            10       100      1083
# 5            39        97       991
# 6            29        21      1074
# 7            46        18      1018
# 8            -2        28       906
# 9            35        44       982
# 10           34        80      1068
# 11           14        29      1005
# 12           21        67      1007
# 13           21         8       906
# 14           14        14       910
# 15           37        77       958
# 16           45        41       945
# 17           18        60       995
# 18           12        42      1064
# 19           13        92      1027

# %%
#line graph with seaborn

import seaborn as sns

import matplotlib.pyplot as plt

sns.lineplot(data=df)

plt.show()

# %%
pip install bokeh

# %%
#pie graph using bokeh

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

from bokeh.plotting import figure, show, output_file

from bokeh.io import output_notebook

from bokeh.transform import cumsum

from math import pi

from bokeh.palettes import Category20 # Import Category20 for more colors

output_notebook()


# Assuming the first column is the category and the second column is the value

data = df.set_index(df.columns[0]).iloc[:, 0]

data = data.reset_index(name='value').rename(columns={df.columns[0]: 'category'})

data['angle'] = data['value']/data['value'].sum() * 2*pi

data['color'] = [Category20[20][i % 20] for i in range(len(data))]

p = figure(height=350, title="Pie Chart", toolbar_location=None,

           tools="hover", tooltips="@category: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,

        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),

        line_color="white", fill_color='color', legend_field='category', source=data)

p.axis.axis_label = None

p.axis.visible = False

p.grid.grid_line_color = None


show(p)
# Out:
#   <div id="cf85f675-68da-45fa-80a6-272ecdb1dc48" data-root-id="p1089" style="display: contents;"></div>

# %%
#Bar Plot

import matplotlib.pyplot as plt

import numpy as np # Import numpy

# Data

temperature = [23, 39, 8, 46, 10, 39, 29, 46, -2, 35, 34, 14, 21, 21, 14, 37, 45, 18, 12, 13]

humidity = [63, 87, 8, 50, 100, 97, 21, 18, 28, 44, 80, 29, 67, 8, 14, 77, 41, 60, 42, 92]

pressure = [947, 1073, 941, 930, 1083, 991, 1074, 1018, 906, 982, 1068, 1005, 1007, 906, 910, 958, 945, 995, 1064, 1027]

# Create a figure and axes

fig, ax = plt.subplots()

# Create bar plots for each variable

x = range(len(temperature))

width = 0.25

rects1 = ax.bar(x, temperature, width, label='Temperature')

# Convert x to a NumPy array to enable element-wise addition with 'width'

rects2 = ax.bar(np.array(x) + width, humidity, width, label='Humidity')

rects3 = ax.bar(np.array(x) + 2*width, pressure, width, label='Pressure')

# Add labels and title

ax.set_xlabel('Data Point')

ax.set_ylabel('Value')

ax.set_title('Temperature, Humidity, and Pressure')

ax.set_xticks(np.array(x) + width) # Also adjust the x-ticks for centering

ax.set_xticklabels(range(1, len(temperature) + 1))

ax.legend()

plt.show()
